# %%
import pandas as pd
import os
from pathlib import Path
from datetime import datetime
import numpy as np

# %%
files = os.listdir('./example_data')

# %%
folder = Path('./example_data')

# %%
df = pd.read_csv(folder/files[0], delimiter=' ', header=0, index_col=False, na_values='None', na_filter=True)

# %%
df.head()
# Out:
#       timestamp  temperature   humidity    pressure pm10_standard  \
# 0  1.631690e+09    18.556641  59.972400  983.460223             7
# 1  1.631690e+09    18.556641  59.925254  983.444045             6
# 2  1.631690e+09    18.551562  60.065809  983.457467             6
# 3  1.631690e+09    18.551562  59.960229  983.445723             5
# 4  1.631690e+09    18.541406  59.784037  983.456089             6
#
#   pm25_standard pm100_standard pm10_env pm25_env pm100_env particles_03um  \
# 0             9              9        7        9         9           2520
# 1             9              9        6        9         9           2526
# 2             9              9        6        9         9           2526
# 3             8              8        5        8         8           2526
# 4             9              9        6        9         9           2532
#
#   particles_05um particles_10um particles_25um particles_50um particles_100um
# 0            388             45              2              0               0
# 1            374             45              2              0               0
# 2            374             45              2              0               0
# 3            374             45              2              0               0
# 4            393             45              4              0               0
